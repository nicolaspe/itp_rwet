# %% [markdown]
# # scraping for recipes
#
# This notebook is used to test packages for scraping the web for different recipes. Thanks to [hhursev](https://github.com/hhursev) for the [recipe scraper package](https://github.com/hhursev/recipe-scrapers)

# %%
# !pip install git+git://github.com/hhursev/recipe-scrapers.git

# %% [markdown]
# ## Packages

# %%
# recipe scraper package
from recipe_scrapers import scrape_me

# %%
# spacy and nlp module
import spacy
nlp = spacy.load('en_core_web_md')

# %%
def remove_all(bye, words):
    while(bye in words):
        words.remove(bye)

# %% [markdown]
# ## get source recipes

# %%
drinks_sources = [line.strip() for line in open('./recipe_sources.txt').readlines()]

# %%
drinks_scrape = [scrape_me(item) for item in drinks_sources]

# %% [markdown]
# Now, I need to take the different types of contents. The ones I'll use (for now) are ingredients and instructions

# %% [markdown]
# #### Ingredients

# %%
ingredients = []
[ingredients.extend(drink.ingredients()) for drink in drinks_scrape]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# Now I need to separate the numbers, the amount units and strip away the nouns...

# %%
ingredients
# Out:
# ['2 fluid ounces dark rum',
#  '4 fluid ounces ginger beer',
#  '1/2 cup ice',
#  '10 fresh mint leaves',
#  '1/2 lime, cut into 4 wedges',
#  '2 tablespoons white sugar, or to taste',
#  '1 cup ice cubes',
#  '1 1/2 fluid ounces white rum',
#  '1/2 cup club soda',
#  '5 fluid ounces tequila',
#  '3 fluid ounces fresh lime juice',
#  '1 fluid ounce sweetened lime juice',
#  '3 fluid ounces triple sec (orange-flavored liqueur)',
#  'ice cubes',
#  '1 lime, cut into wedges',
#  'rimming salt',
#  '6 mint leaves',
#  '4 teaspoons white sugar',
#  '1 lime, cut into 6 wedges',
#  '2 (1.5 fluid ounce) jiggers lemon-flavored rum',
#  '1 cup ice cubes, or as needed',
#  '1/2 cup carbonated water, or as needed',
#  '3 cups bottled Bloody Mary mix',
#  '1 tablespoon prepared horseradish',
#  '1 teaspoon chopped fresh dill',
#  "1 teaspoon hot pepper sauce (such as Frank's RedHot®)",
#  '2 tablespoons dill pickle juice',
#  '1/2 cup kosher salt',
#  '1 teaspoon ground black pepper',
#  '1 teaspoon celery seed',
#  '1 lime, juiced',
#  '6 (1.5 fluid ounce) jiggers vodka (optional)',
#  '6 dill pickle spears',
#  '1 fresh lime, cut into wedges',
#  '6 fluid ounces tequila',
#  '2 fluid ounces triple sec',
#  '8 ounces frozen sliced strawberries in syrup',
#  '4 fluid ounces frozen limeade concentrate',
#  "1 cup Pimm's No. 1™ (gin-based liqueur)",
#  '2 quarts lemonade',
#  '1 (4 inch) wedge of cucumber',
#  '1 red apple, cored and thinly sliced',
#  '1 orange, sliced',
#  '1/2 lemon, sliced',
#  '1/2 lime, sliced',
#  '2 slices fresh pineapple (optional)',
#  '2 strawberries, sliced (optional)',
#  '3 leaves fresh mint',
#  '1 (12 fluid ounce) can frozen limeade concentrate',
#  '12 fluid ounces tequila',
#  '12 fluid ounces water',
#  '12 fluid ounces beer',
#  'ice',
#  '1 lime, cut into wedges',
#  '1 cup coconut milk',
#  '1 cup pineapple juice',
#  '1/2 cup rum',
#  '4 tablespoons white sugar',
#  '8 cubes ice',
#  '1 (1.5 fluid ounce) jigger vodka',
#  '1/2 fluid ounce cointreau',
#  '1 teaspoon fresh lime juice',
#  '1 1/2 fluid ounces cranberry juice',
#  '1 twist lime zest, garnish',
#  '3/4 cup champagne, chilled',
#  '1/4 cup orange juice',
#  '2/3 cup pineapple juice, chilled',
#  '1/3 cup vanilla flavored vodka',
#  '1 dash grenadine syrup',
#  '2 pineapple wedges',
#  '2 maraschino cherries',
#  '1 cup ice cubes',
#  '2 fluid ounces vodka',
#  '4 fluid ounces cranberry juice',
#  '1/2 fluid ounce orange juice']

# %% [markdown]
# For the ingredients, I will just create lists by hand. It is better, as I won't be able to control certain measures otherwise.

# %%
ingr_extra = ["fresh mint leaves",
             "1 lime, cut into wedges",
             "ice cubes",
             "rimming salt",
             "1 orange, sliced",
             "twist lime zest",
             "maraschino cherries",
             "pineapple wedges"]

# %%
ingr_units = ["fluid oz.",
             "tablespoons",
             "teaspoons",
             "oz."]

# %% [markdown]
# ### Instructions
#
# From these, I'm mainly interested in the verbs

# %%
instructions = []
[instructions.append(drink.instructions()) for drink in drinks_scrape]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# It would be helpful to be able to analyse the last sentence of every set of instructions separately, as they are often different and wrap everything up nicely.

# %%
nlp_instructions = [list(nlp(inst).sents) for inst in instructions]

# %%
nlp_instructions
# Out:
# [[Combine rum and ginger beer in an old-fashioned glass., Add ice and stir.],
#  [Place mint leaves and 1 lime wedge into a sturdy glass.,
#   Use a muddler to crush the mint and lime to release the mint oils and lime juice.,
#   Add 2 more lime wedges and the sugar, and muddle again to release the lime juice.,
#   Do not strain the mixture.,
#   Fill the glass almost to the top with ice.,
#   Pour the rum over the ice, and fill the glass with carbonated water.,
#   Stir, taste, and add more sugar if desired.,
#   Garnish with the remaining lime wedge.],
#  [Measure the tequila, lime juice, sweetened lime juice and triple sec into a cocktail shaker and add a generous scoop of ice.,
#   Cover and shake until the shaker is frosty, about 30 seconds.,
#   Rub a lime wedge around the rim of a margarita glass and dip in salt.,
#   Fill each glass with ice.,
#   Strain equal amounts of the cocktail into the glasses to serve.,
#   Garnish with a lime wedge.],
#  [Put 3 mint leaves and 2 teaspoons sugar into each of 2 glass tumblers; vigorously stir sugar and mint together, crushing mint with the back of a spoon to release oils.,
#   Add 3 lime wedges to each glass; again stir vigorously to release some lime juice.,
#   Pour 1 jigger rum into each glass.,
#   Fill glasses with ice cubes and top with carbonated water; stir.],
#  [In a large pitcher, stir together the Bloody Mary mix, horseradish, dill, hot pepper sauce, and dill pickle juice.,
#   Taste and adjust seasoning if desired.,
#   In a shallow dish, stir together the kosher salt, pepper and celery seed.,
#   Pour the lime juice onto a saucer.,
#   Dip each glass into the lime juice to coat the rim, then into the spice mixture.,
#   Fill each glass with ice.,
#   Pour one shot of vodka into each glass if using.,
#   Fill with the Bloody Mary mixture.,
#   Garnish each glass with a wedge of lime and a dill pickle spear.],
#  [Fill a blender with ice and crush.,
#   Pour in the tequila and triple sec.,
#   Add the strawberries and limeade.,
#   Blend for 30 seconds or until smooth.,
#   Serve in margarita glasses with the rims dipped in powdered sugar.],
#  [Stir together the Pimm's liqueur and lemonade together in a serving pitcher.,
#   Add the cucumber wedge, apple, orange, lemon, lime, pineapple, strawberries, and mint.,
#   Refrigerate until cold, or serve over ice.],
#  [Pour limeade, tequila, water, and beer into a large pitcher.,
#   Stir until well-blended, and limeade has melted.,
#   Add plenty of ice, and garnish with lime wedges.,
#   Adjust with additional water, if needed.],
#  [In a blender, combine coconut milk, pineapple juice, rum, sugar and ice.,
#   Blend until smooth.,
#   Pour into glasses, and serve immediately.],
#  [Pour all the ingredients into a shaker with lots of ice.,
#   Shake vigorously for several seconds and strain into a cocktail glass.,
#   Garnish with a lime twist.],
#  [Mix three parts of your favorite sparkling white to one part of your favorite orange juice.,
#   Enjoy!],
#  [Pour the pineapple juice, vodka and grenadine into a shaker full of ice.,
#   Shake, then strain into two martini glasses.,
#   Garnish with a piece of pineapple and a cherry on a skewer.],
#  [Fill a tall glass with ice.,
#   Pour in vodka.,
#   Fill glass to 3/4 full with cranberry juice.,
#   Top with orange juice.,
#   Stir.]]

# %%
for instr_set in nlp_instructions:
    for sent in instr_set:
        print("==========")
        print(sent.text)
        for word in sent:
            if word.tag_ in ["VB", "VBN"]:
                print(".text: ", word.text)
                print(".tag_: ", word.tag_)
                print(".head: ", word.head.text)
                print(".children: ", list(word.children))
                for ch in list(word.children):
                    print("  -ch.text: ", ch.text)
                    print("  -ch.tag_: ", ch.tag_)
                    print("  -ch.dep_: ", ch.dep_)
                    if(ch.dep_ in ["prep", "dobj"]):
                        print("    -ch.subtree", list(ch.subtree))
                print()
# Out:
# ==========
# Combine rum and ginger beer in an old-fashioned glass.
# .text:  Combine
# .tag_:  VB
# .head:  rum
# .children:  []
#
# ==========
# Add ice and stir.
#
# .text:  Add
# .tag_:  VB
# .head:  Add
# .children:  [ice, and, stir, .]
#   -ch.text:  ice
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [ice]
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  stir
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  stir
# .tag_:  VB
# .head:  Add
# .children:  []
#
# ==========
# Place mint leaves and 1 lime wedge into a sturdy glass.
# .text:  Place
# .tag_:  VB
# .head:  leaves
# .children:  []
#
# ==========
# Use a muddler to crush the mint and lime to release the mint oils and lime juice.
# .text:  Use
# .tag_:  VB
# .head:  Use
# .children:  [muddler, .]
#   -ch.text:  muddler
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [a, muddler, to, crush, the, mint, and, lime, to, release, the, mint, oils, and, lime, juice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  crush
# .tag_:  VB
# .head:  muddler
# .children:  [to, mint, release]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#   -ch.text:  mint
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, mint, and, lime]
#   -ch.text:  release
#   -ch.tag_:  VB
#   -ch.dep_:  advcl
#
# .text:  release
# .tag_:  VB
# .head:  crush
# .children:  [to, oils]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#   -ch.text:  oils
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [the, mint, oils, and, lime, juice]
#
# ==========
# Add 2 more lime wedges and the sugar, and muddle again to release the lime juice.
# .text:  Add
# .tag_:  VB
# .head:  Add
# .children:  [2, wedges, ,, and, muddle, .]
#   -ch.text:  2
#   -ch.tag_:  CD
#   -ch.dep_:  dobj
#     -ch.subtree [2]
#   -ch.text:  wedges
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [more, lime, wedges, and, the, sugar]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  muddle
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  muddle
# .tag_:  VB
# .head:  Add
# .children:  [again, release]
#   -ch.text:  again
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  release
#   -ch.tag_:  VB
#   -ch.dep_:  advcl
#
# .text:  release
# .tag_:  VB
# .head:  muddle
# .children:  [to, juice]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#   -ch.text:  juice
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, lime, juice]
#
# ==========
# Do not strain the mixture.
# .text:  Do
# .tag_:  VB
# .head:  strain
# .children:  []
#
# .text:  strain
# .tag_:  VB
# .head:  strain
# .children:  [Do, not, mixture, .]
#   -ch.text:  Do
#   -ch.tag_:  VB
#   -ch.dep_:  aux
#   -ch.text:  not
#   -ch.tag_:  RB
#   -ch.dep_:  neg
#   -ch.text:  mixture
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, mixture]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Fill the glass almost to the top with ice.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [glass, to, with, .]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, glass]
#   -ch.text:  to
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [almost, to, the, top]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Pour the rum over the ice, and fill the glass with carbonated water.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [rum, ,, and, fill, .]
#   -ch.text:  rum
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, rum, over, the, ice]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  fill
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  fill
# .tag_:  VB
# .head:  Pour
# .children:  [glass, with]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, glass]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, carbonated, water]
#
# ==========
# Stir, taste, and add more sugar if desired.
# .text:  Stir
# .tag_:  VB
# .head:  Stir
# .children:  [,, taste, ,, and, add, .]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  taste
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  add
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  taste
# .tag_:  VB
# .head:  Stir
# .children:  []
#
# .text:  add
# .tag_:  VB
# .head:  Stir
# .children:  [sugar, desired]
#   -ch.text:  sugar
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [more, sugar]
#   -ch.text:  desired
#   -ch.tag_:  VBN
#   -ch.dep_:  advcl
#
# .text:  desired
# .tag_:  VBN
# .head:  add
# .children:  [if]
#   -ch.text:  if
#   -ch.tag_:  IN
#   -ch.dep_:  mark
#
# ==========
# Garnish with the remaining lime wedge.
#
# .text:  Garnish
# .tag_:  VBN
# .head:  Garnish
# .children:  [with, .]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, the, remaining, lime, wedge]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Measure the tequila, lime juice, sweetened lime juice and triple sec into a cocktail shaker and add a generous scoop of ice.
# .text:  Measure
# .tag_:  VB
# .head:  Measure
# .children:  [tequila, into, and, add, .]
#   -ch.text:  tequila
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, tequila, ,, lime, juice, ,, sweetened, lime, juice, and, triple, sec]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, a, cocktail, shaker]
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  add
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  sweetened
# .tag_:  VBN
# .head:  juice
# .children:  []
#
# .text:  add
# .tag_:  VB
# .head:  Measure
# .children:  [scoop]
#   -ch.text:  scoop
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [a, generous, scoop, of, ice]
#
# ==========
# Cover and shake until the shaker is frosty, about 30 seconds.
#
# .text:  shake
# .tag_:  VB
# .head:  Cover
# .children:  [is]
#   -ch.text:  is
#   -ch.tag_:  VBZ
#   -ch.dep_:  advcl
#
# ==========
# Rub a lime wedge around the rim of a margarita glass and dip in salt.
# .text:  Rub
# .tag_:  VB
# .head:  Rub
# .children:  [wedge, around, .]
#   -ch.text:  wedge
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [a, lime, wedge]
#   -ch.text:  around
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [around, the, rim, of, a, margarita, glass, and, dip, in, salt]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Fill each glass with ice.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [glass, with, .]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [each, glass]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Strain equal amounts of the cocktail into the glasses to serve.
# .text:  Strain
# .tag_:  VB
# .head:  equal
# .children:  []
#
# .text:  serve
# .tag_:  VB
# .head:  equal
# .children:  [to]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#
# ==========
# Garnish with a lime wedge.
#
# .text:  Garnish
# .tag_:  VBN
# .head:  Garnish
# .children:  [with, .]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, a, lime, wedge]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Put 3 mint leaves and 2 teaspoons sugar into each of 2 glass tumblers; vigorously stir sugar and mint together, crushing mint with the back of a spoon to release oils.
# .text:  Put
# .tag_:  VB
# .head:  Put
# .children:  [leaves, into, ;, stir, .]
#   -ch.text:  leaves
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [3, mint, leaves, and, 2, teaspoons, sugar]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, each, of, 2, glass, tumblers]
#   -ch.text:  ;
#   -ch.tag_:  :
#   -ch.dep_:  punct
#   -ch.text:  stir
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  stir
# .tag_:  VB
# .head:  Put
# .children:  [vigorously, sugar, together, ,, crushing]
#   -ch.text:  vigorously
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  sugar
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [sugar, and, mint]
#   -ch.text:  together
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  crushing
#   -ch.tag_:  VBG
#   -ch.dep_:  advcl
#
# .text:  release
# .tag_:  VB
# .head:  crushing
# .children:  [to, oils]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#   -ch.text:  oils
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [oils]
#
# ==========
# Add 3 lime wedges to each glass; again stir vigorously to release some lime juice.
# .text:  Add
# .tag_:  VB
# .head:  Add
# .children:  [wedges, to, ;, again, stir, .]
#   -ch.text:  wedges
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [3, lime, wedges]
#   -ch.text:  to
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [to, each, glass]
#   -ch.text:  ;
#   -ch.tag_:  :
#   -ch.dep_:  punct
#   -ch.text:  again
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  stir
#   -ch.tag_:  VBP
#   -ch.dep_:  dep
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  release
# .tag_:  VB
# .head:  stir
# .children:  [to, juice]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#   -ch.text:  juice
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [some, lime, juice]
#
# ==========
# Pour 1 jigger rum into each glass.
# ==========
# Fill glasses with ice cubes and top with carbonated water; stir.
#
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [glasses, with, ;, stir, .]
#   -ch.text:  glasses
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [glasses]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, ice, cubes, and, top, with, carbonated, water]
#   -ch.text:  ;
#   -ch.tag_:  :
#   -ch.dep_:  punct
#   -ch.text:  stir
#   -ch.tag_:  NN
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# In a large pitcher, stir together the Bloody Mary mix, horseradish, dill, hot pepper sauce, and dill pickle juice.
# .text:  stir
# .tag_:  VB
# .head:  stir
# .children:  [In, ,, together, mix, .]
#   -ch.text:  In
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [In, a, large, pitcher]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  together
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  mix
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, Bloody, Mary, mix, ,, horseradish, ,, dill, ,, hot, pepper, sauce, ,, and, dill, pickle, juice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Taste and adjust seasoning if desired.
#
# .text:  adjust
# .tag_:  VB
# .head:  Taste
# .children:  [seasoning, desired]
#   -ch.text:  seasoning
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [seasoning]
#   -ch.text:  desired
#   -ch.tag_:  VBN
#   -ch.dep_:  advcl
#
# .text:  desired
# .tag_:  VBN
# .head:  adjust
# .children:  [if]
#   -ch.text:  if
#   -ch.tag_:  IN
#   -ch.dep_:  mark
#
# ==========
# In a shallow dish, stir together the kosher salt, pepper and celery seed.
# .text:  stir
# .tag_:  VB
# .head:  stir
# .children:  [In, ,, together, salt, .]
#   -ch.text:  In
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [In, a, shallow, dish]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  together
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  salt
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, kosher, salt, ,, pepper, and, celery, seed]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Pour the lime juice onto a saucer.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [juice, onto, .]
#   -ch.text:  juice
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, lime, juice]
#   -ch.text:  onto
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [onto, a, saucer]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Dip each glass into the lime juice to coat the rim, then into the spice mixture.
# .text:  Dip
# .tag_:  VB
# .head:  Dip
# .children:  [glass, into, coat, ,, into, .]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [each, glass]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, the, lime, juice]
#   -ch.text:  coat
#   -ch.tag_:  VB
#   -ch.dep_:  advcl
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [then, into, the, spice, mixture]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  coat
# .tag_:  VB
# .head:  Dip
# .children:  [to, rim]
#   -ch.text:  to
#   -ch.tag_:  TO
#   -ch.dep_:  aux
#   -ch.text:  rim
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, rim]
#
# ==========
# Fill each glass with ice.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [glass, with, .]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [each, glass]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Pour one shot of vodka into each glass if using.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [shot, using, .]
#   -ch.text:  shot
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [one, shot, of, vodka, into, each, glass]
#   -ch.text:  using
#   -ch.tag_:  VBG
#   -ch.dep_:  advcl
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Fill with the Bloody Mary mixture.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [with, .]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, the, Bloody, Mary, mixture]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Garnish each glass with a wedge of lime and a dill pickle spear.
#
# .text:  Garnish
# .tag_:  VBN
# .head:  glass
# .children:  []
#
# ==========
# Fill a blender with ice and crush.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [blender, with, .]
#   -ch.text:  blender
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [a, blender]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, ice, and, crush]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Pour in the tequila and triple sec.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [in, .]
#   -ch.text:  in
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [in, the, tequila, and, triple, sec]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Add the strawberries and limeade.
# .text:  Add
# .tag_:  VB
# .head:  Add
# .children:  [strawberries, .]
#   -ch.text:  strawberries
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [the, strawberries, and, limeade]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Blend for 30 seconds or until smooth.
# .text:  Blend
# .tag_:  VB
# .head:  Blend
# .children:  [for, .]
#   -ch.text:  for
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [for, 30, seconds, or, until, smooth]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Serve in margarita glasses with the rims dipped in powdered sugar.
#
# .text:  Serve
# .tag_:  VB
# .head:  Serve
# .children:  [in, with, .]
#   -ch.text:  in
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [in, margarita, glasses]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, the, rims, dipped, in, powdered, sugar]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  dipped
# .tag_:  VBN
# .head:  rims
# .children:  [in]
#   -ch.text:  in
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [in, powdered, sugar]
#
# ==========
# Stir together the Pimm's liqueur and lemonade together in a serving pitcher.
# .text:  Stir
# .tag_:  VB
# .head:  Stir
# .children:  [together, liqueur, in, .]
#   -ch.text:  together
#   -ch.tag_:  RB
#   -ch.dep_:  prt
#   -ch.text:  liqueur
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, Pimm, 's, liqueur, and, lemonade]
#   -ch.text:  in
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [together, in, a, serving, pitcher]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Add the cucumber wedge, apple, orange, lemon, lime, pineapple, strawberries, and mint.
# .text:  Add
# .tag_:  VB
# .head:  Add
# .children:  [wedge, .]
#   -ch.text:  wedge
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, cucumber, wedge, ,, apple, ,, orange, ,, lemon, ,, lime, ,, pineapple, ,, strawberries, ,, and, mint]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Refrigerate until cold, or serve over ice.
#
# .text:  serve
# .tag_:  VB
# .head:  Refrigerate
# .children:  [over]
#   -ch.text:  over
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [over, ice]
#
# ==========
# Pour limeade, tequila, water, and beer into a large pitcher.
# ==========
# Stir until well-blended, and limeade has melted.
# .text:  Stir
# .tag_:  VB
# .head:  Stir
# .children:  [until, ,, and, melted]
#   -ch.text:  until
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [until, well, -, blended]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  melted
#   -ch.tag_:  VBN
#   -ch.dep_:  conj
#
# .text:  melted
# .tag_:  VBN
# .head:  Stir
# .children:  [limeade, has, .]
#   -ch.text:  limeade
#   -ch.tag_:  NN
#   -ch.dep_:  nsubj
#   -ch.text:  has
#   -ch.tag_:  VBZ
#   -ch.dep_:  aux
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Add plenty of ice, and garnish with lime wedges.
# .text:  Add
# .tag_:  VB
# .head:  Add
# .children:  [plenty, ,, and, garnish, .]
#   -ch.text:  plenty
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [plenty, of, ice]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  garnish
#   -ch.tag_:  VBN
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  garnish
# .tag_:  VBN
# .head:  Add
# .children:  [with]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, lime, wedges]
#
# ==========
# Adjust with additional water, if needed.
#
# .text:  Adjust
# .tag_:  VB
# .head:  Adjust
# .children:  [with, needed]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, additional, water]
#   -ch.text:  needed
#   -ch.tag_:  VBN
#   -ch.dep_:  advcl
#
# .text:  needed
# .tag_:  VBN
# .head:  Adjust
# .children:  [,, if, .]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  if
#   -ch.tag_:  IN
#   -ch.dep_:  mark
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# In a blender, combine coconut milk, pineapple juice, rum, sugar and ice.
# .text:  combine
# .tag_:  VB
# .head:  combine
# .children:  [In, ,, milk, .]
#   -ch.text:  In
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [In, a, blender]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  milk
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [coconut, milk, ,, pineapple, juice, ,, rum, ,, sugar, and, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Blend until smooth.
# ==========
# Pour into glasses, and serve immediately.
#
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [into, ,, and, serve, .]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, glasses]
#   -ch.text:  ,
#   -ch.tag_:  ,
#   -ch.dep_:  punct
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  serve
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  serve
# .tag_:  VB
# .head:  Pour
# .children:  [immediately]
#   -ch.text:  immediately
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#
# ==========
# Pour all the ingredients into a shaker with lots of ice.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [ingredients, into, with, .]
#   -ch.text:  ingredients
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [all, the, ingredients]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, a, shaker]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, lots, of, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Shake vigorously for several seconds and strain into a cocktail glass.
# .text:  Shake
# .tag_:  VB
# .head:  Shake
# .children:  [vigorously, for, and, strain, .]
#   -ch.text:  vigorously
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  for
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [for, several, seconds]
#   -ch.text:  and
#   -ch.tag_:  CC
#   -ch.dep_:  cc
#   -ch.text:  strain
#   -ch.tag_:  VB
#   -ch.dep_:  conj
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# .text:  strain
# .tag_:  VB
# .head:  Shake
# .children:  [into]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, a, cocktail, glass]
#
# ==========
# Garnish with a lime twist.
#
# .text:  Garnish
# .tag_:  VBN
# .head:  Garnish
# .children:  [with, .]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, a, lime, twist]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Mix three parts of your favorite sparkling white to one part of your favorite orange juice.
# .text:  Mix
# .tag_:  VB
# .head:  Mix
# .children:  [parts, to, .]
#   -ch.text:  parts
#   -ch.tag_:  NNS
#   -ch.dep_:  dobj
#     -ch.subtree [three, parts, of, your, favorite, sparkling, white]
#   -ch.text:  to
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [to, one, part, of, your, favorite, orange, juice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Enjoy!
#
# .text:  Enjoy
# .tag_:  VB
# .head:  Enjoy
# .children:  [!]
#   -ch.text:  !
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Pour the pineapple juice, vodka and grenadine into a shaker full of ice.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [juice, into, .]
#   -ch.text:  juice
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [the, pineapple, juice, ,, vodka, and, grenadine]
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, a, shaker, full, of, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Shake, then strain into two martini glasses.
# .text:  strain
# .tag_:  VB
# .head:  strain
# .children:  [Shake, then, into, .]
#   -ch.text:  Shake
#   -ch.tag_:  NN
#   -ch.dep_:  advcl
#   -ch.text:  then
#   -ch.tag_:  RB
#   -ch.dep_:  advmod
#   -ch.text:  into
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [into, two, martini, glasses]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Garnish with a piece of pineapple and a cherry on a skewer.
#
# .text:  Garnish
# .tag_:  VBN
# .head:  Garnish
# .children:  [with, .]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, a, piece, of, pineapple, and, a, cherry, on, a, skewer]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Fill a tall glass with ice.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [glass, with, .]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [a, tall, glass]
#   -ch.text:  with
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [with, ice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Pour in vodka.
# .text:  Pour
# .tag_:  VB
# .head:  Pour
# .children:  [in, .]
#   -ch.text:  in
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [in, vodka]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Fill glass to 3/4 full with cranberry juice.
# .text:  Fill
# .tag_:  VB
# .head:  Fill
# .children:  [glass, to, .]
#   -ch.text:  glass
#   -ch.tag_:  NN
#   -ch.dep_:  dobj
#     -ch.subtree [glass]
#   -ch.text:  to
#   -ch.tag_:  IN
#   -ch.dep_:  prep
#     -ch.subtree [to, 3/4, full, with, cranberry, juice]
#   -ch.text:  .
#   -ch.tag_:  .
#   -ch.dep_:  punct
#
# ==========
# Top with orange juice.
# ==========
# Stir.

# %%
def verb_tracer_simple(s):
    verb = ""
    for word in s:
        if word.tag_ in ["VB", "VBN"]:
            verb = word
    if verb is "":
        return ""
    elif len(list(verb.children)) > 0:
        prep_children = [ch for ch in list(verb.children) if ch.dep_ in ["prep", "dobj"]]
        return verb.text + " " + " ".join([ch.text+" #np#" for ch in prep_children])
    else:
        return verb.text+" #np#"

# %%
def subtree_flatten(children_list):
    sub = []
    for ch in children_list:
        sub.append(" ".join([word.text for word in ch.subtree]))
    return " ".join(sub)

# %%
def verb_tracer_subtree(s):
    verb = ""
    for word in s:
        if word.tag_ in ["VB", "VBN"]:
            verb = word
    if verb is "":
        return ""
    elif len(list(verb.children)) > 0:
        prep_children = [ch for ch in list(verb.children) if ch.dep_ in ["prep", "dobj"]]
        return verb.text + " " + subtree_flatten(prep_children)
#         return verb.text + " " + " ".join([ch.text+" #np#" for ch in prep_children])
    else:
        return verb.text+" #np#"

# %%
# compare both functions
for instr_set in nlp_instructions:
    for sent in instr_set:
        print("")
        print("=========")
        print(sent.text)
        print(verb_tracer_simple(sent))
        print(verb_tracer_subtree(sent))
# Out:
# =========
# Combine rum and ginger beer in an old-fashioned glass.
# Combine #np#
# Combine #np#
#
# =========
# Add ice and stir.
#
# stir #np#
# stir #np#
#
# =========
# Place mint leaves and 1 lime wedge into a sturdy glass.
# Place #np#
# Place #np#
#
# =========
# Use a muddler to crush the mint and lime to release the mint oils and lime juice.
# release oils #np#
# release the mint oils and lime juice
#
# =========
# Add 2 more lime wedges and the sugar, and muddle again to release the lime juice.
# release juice #np#
# release the lime juice
#
# =========
# Do not strain the mixture.
# strain mixture #np#
# strain the mixture
#
# =========
# Fill the glass almost to the top with ice.
# Fill glass #np# to #np# with #np#
# Fill the glass almost to the top with ice
#
# =========
# Pour the rum over the ice, and fill the glass with carbonated water.
# fill glass #np# with #np#
# fill the glass with carbonated water
#
# =========
# Stir, taste, and add more sugar if desired.
# desired
# desired
#
# =========
# Garnish with the remaining lime wedge.
#
# Garnish with #np#
# Garnish with the remaining lime wedge
#
# =========
# Measure the tequila, lime juice, sweetened lime juice and triple sec into a cocktail shaker and add a generous scoop of ice.
# add scoop #np#
# add a generous scoop of ice
#
# =========
# Cover and shake until the shaker is frosty, about 30 seconds.
#
# shake
# shake
#
# =========
# Rub a lime wedge around the rim of a margarita glass and dip in salt.
# Rub wedge #np# around #np#
# Rub a lime wedge around the rim of a margarita glass and dip in salt
#
# =========
# Fill each glass with ice.
# Fill glass #np# with #np#
# Fill each glass with ice
#
# =========
# Strain equal amounts of the cocktail into the glasses to serve.
# serve
# serve
#
# =========
# Garnish with a lime wedge.
#
# Garnish with #np#
# Garnish with a lime wedge
#
# =========
# Put 3 mint leaves and 2 teaspoons sugar into each of 2 glass tumblers; vigorously stir sugar and mint together, crushing mint with the back of a spoon to release oils.
# release oils #np#
# release oils
#
# =========
# Add 3 lime wedges to each glass; again stir vigorously to release some lime juice.
# release juice #np#
# release some lime juice
#
# =========
# Pour 1 jigger rum into each glass.
#
#
#
# =========
# Fill glasses with ice cubes and top with carbonated water; stir.
#
# Fill glasses #np# with #np#
# Fill glasses with ice cubes and top with carbonated water
#
# =========
# In a large pitcher, stir together the Bloody Mary mix, horseradish, dill, hot pepper sauce, and dill pickle juice.
# stir In #np# mix #np#
# stir In a large pitcher the Bloody Mary mix , horseradish , dill , hot pepper sauce , and dill pickle juice
#
# =========
# Taste and adjust seasoning if desired.
#
# desired
# desired
#
# =========
# In a shallow dish, stir together the kosher salt, pepper and celery seed.
# stir In #np# salt #np#
# stir In a shallow dish the kosher salt , pepper and celery seed
#
# =========
# Pour the lime juice onto a saucer.
# Pour juice #np# onto #np#
# Pour the lime juice onto a saucer
#
# =========
# Dip each glass into the lime juice to coat the rim, then into the spice mixture.
# coat rim #np#
# coat the rim
#
# =========
# Fill each glass with ice.
# Fill glass #np# with #np#
# Fill each glass with ice
#
# =========
# Pour one shot of vodka into each glass if using.
# Pour shot #np#
# Pour one shot of vodka into each glass
#
# =========
# Fill with the Bloody Mary mixture.
# Fill with #np#
# Fill with the Bloody Mary mixture
#
# =========
# Garnish each glass with a wedge of lime and a dill pickle spear.
#
# Garnish #np#
# Garnish #np#
#
# =========
# Fill a blender with ice and crush.
# Fill blender #np# with #np#
# Fill a blender with ice and crush
#
# =========
# Pour in the tequila and triple sec.
# Pour in #np#
# Pour in the tequila and triple sec
#
# =========
# Add the strawberries and limeade.
# Add strawberries #np#
# Add the strawberries and limeade
#
# =========
# Blend for 30 seconds or until smooth.
# Blend for #np#
# Blend for 30 seconds or until smooth
#
# =========
# Serve in margarita glasses with the rims dipped in powdered sugar.
#
# dipped in #np#
# dipped in powdered sugar
#
# =========
# Stir together the Pimm's liqueur and lemonade together in a serving pitcher.
# Stir liqueur #np# in #np#
# Stir the Pimm 's liqueur and lemonade together in a serving pitcher
#
# =========
# Add the cucumber wedge, apple, orange, lemon, lime, pineapple, strawberries, and mint.
# Add wedge #np#
# Add the cucumber wedge , apple , orange , lemon , lime , pineapple , strawberries , and mint
#
# =========
# Refrigerate until cold, or serve over ice.
#
# serve over #np#
# serve over ice
#
# =========
# Pour limeade, tequila, water, and beer into a large pitcher.
#
#
#
# =========
# Stir until well-blended, and limeade has melted.
# melted
# melted
#
# =========
# Add plenty of ice, and garnish with lime wedges.
# garnish with #np#
# garnish with lime wedges
#
# =========
# Adjust with additional water, if needed.
#
# needed
# needed
#
# =========
# In a blender, combine coconut milk, pineapple juice, rum, sugar and ice.
# combine In #np# milk #np#
# combine In a blender coconut milk , pineapple juice , rum , sugar and ice
#
# =========
# Blend until smooth.
#
#
#
# =========
# Pour into glasses, and serve immediately.
#
# serve
# serve
#
# =========
# Pour all the ingredients into a shaker with lots of ice.
# Pour ingredients #np# into #np# with #np#
# Pour all the ingredients into a shaker with lots of ice
#
# =========
# Shake vigorously for several seconds and strain into a cocktail glass.
# strain into #np#
# strain into a cocktail glass
#
# =========
# Garnish with a lime twist.
#
# Garnish with #np#
# Garnish with a lime twist
#
# =========
# Mix three parts of your favorite sparkling white to one part of your favorite orange juice.
# Mix parts #np# to #np#
# Mix three parts of your favorite sparkling white to one part of your favorite orange juice
#
# =========
# Enjoy!
#
# Enjoy
# Enjoy
#
# =========
# Pour the pineapple juice, vodka and grenadine into a shaker full of ice.
# Pour juice #np# into #np#
# Pour the pineapple juice , vodka and grenadine into a shaker full of ice
#
# =========
# Shake, then strain into two martini glasses.
# strain into #np#
# strain into two martini glasses
#
# =========
# Garnish with a piece of pineapple and a cherry on a skewer.
#
# Garnish with #np#
# Garnish with a piece of pineapple and a cherry on a skewer
#
# =========
# Fill a tall glass with ice.
# Fill glass #np# with #np#
# Fill a tall glass with ice
#
# =========
# Pour in vodka.
# Pour in #np#
# Pour in vodka
#
# =========
# Fill glass to 3/4 full with cranberry juice.
# Fill glass #np# to #np#
# Fill glass to 3/4 full with cranberry juice
#
# =========
# Top with orange juice.
#
#
#
# =========
# Stir.

# %%
def verb_tracer_smart(s):
    verb = ""
    for word in s:
        if word.tag_ == "VB":
            verb = word
    if verb is "":
        return ""
    elif len(list(verb.children)) > 0:
        prep_children = [ch for ch in list(verb.children) if ch.dep_ == "prep"]
        dobj_children = [ch for ch in list(verb.children) if ch.dep_ == "dobj"]
        return verb.text + " " + subtree_flatten(dobj_children) + " " + " ".join([ch.text+" #np#" for ch in prep_children])
#         return verb.text + " " + subtree_flatten(prep_children)
#         return verb.text + " " + " ".join([ch.text+" #np#" for ch in prep_children])
    else:
        return verb.text+" #np#"

# %%
# almost done function
for instr_set in nlp_instructions:
    for sent in instr_set:
        print("")
        print("=========")
        print(sent.text)
        print(verb_tracer_smart(sent))
# Out:
# =========
# Combine rum and ginger beer in an old-fashioned glass.
# Combine #np#
#
# =========
# Add ice and stir.
#
# stir #np#
#
# =========
# Place mint leaves and 1 lime wedge into a sturdy glass.
# Place #np#
#
# =========
# Use a muddler to crush the mint and lime to release the mint oils and lime juice.
# release the mint oils and lime juice
#
# =========
# Add 2 more lime wedges and the sugar, and muddle again to release the lime juice.
# release the lime juice
#
# =========
# Do not strain the mixture.
# strain the mixture
#
# =========
# Fill the glass almost to the top with ice.
# Fill the glass to #np# with #np#
#
# =========
# Pour the rum over the ice, and fill the glass with carbonated water.
# fill the glass with #np#
#
# =========
# Stir, taste, and add more sugar if desired.
# add more sugar
#
# =========
# Garnish with the remaining lime wedge.
#
#
#
# =========
# Measure the tequila, lime juice, sweetened lime juice and triple sec into a cocktail shaker and add a generous scoop of ice.
# add a generous scoop of ice
#
# =========
# Cover and shake until the shaker is frosty, about 30 seconds.
#
# shake
#
# =========
# Rub a lime wedge around the rim of a margarita glass and dip in salt.
# Rub a lime wedge around #np#
#
# =========
# Fill each glass with ice.
# Fill each glass with #np#
#
# =========
# Strain equal amounts of the cocktail into the glasses to serve.
# serve
#
# =========
# Garnish with a lime wedge.
#
#
#
# =========
# Put 3 mint leaves and 2 teaspoons sugar into each of 2 glass tumblers; vigorously stir sugar and mint together, crushing mint with the back of a spoon to release oils.
# release oils
#
# =========
# Add 3 lime wedges to each glass; again stir vigorously to release some lime juice.
# release some lime juice
#
# =========
# Pour 1 jigger rum into each glass.
#
#
# =========
# Fill glasses with ice cubes and top with carbonated water; stir.
#
# Fill glasses with #np#
#
# =========
# In a large pitcher, stir together the Bloody Mary mix, horseradish, dill, hot pepper sauce, and dill pickle juice.
# stir the Bloody Mary mix , horseradish , dill , hot pepper sauce , and dill pickle juice In #np#
#
# =========
# Taste and adjust seasoning if desired.
#
# adjust seasoning
#
# =========
# In a shallow dish, stir together the kosher salt, pepper and celery seed.
# stir the kosher salt , pepper and celery seed In #np#
#
# =========
# Pour the lime juice onto a saucer.
# Pour the lime juice onto #np#
#
# =========
# Dip each glass into the lime juice to coat the rim, then into the spice mixture.
# coat the rim
#
# =========
# Fill each glass with ice.
# Fill each glass with #np#
#
# =========
# Pour one shot of vodka into each glass if using.
# Pour one shot of vodka into each glass
#
# =========
# Fill with the Bloody Mary mixture.
# Fill  with #np#
#
# =========
# Garnish each glass with a wedge of lime and a dill pickle spear.
#
#
#
# =========
# Fill a blender with ice and crush.
# Fill a blender with #np#
#
# =========
# Pour in the tequila and triple sec.
# Pour  in #np#
#
# =========
# Add the strawberries and limeade.
# Add the strawberries and limeade
#
# =========
# Blend for 30 seconds or until smooth.
# Blend  for #np#
#
# =========
# Serve in margarita glasses with the rims dipped in powdered sugar.
#
# Serve  in #np# with #np#
#
# =========
# Stir together the Pimm's liqueur and lemonade together in a serving pitcher.
# Stir the Pimm 's liqueur and lemonade in #np#
#
# =========
# Add the cucumber wedge, apple, orange, lemon, lime, pineapple, strawberries, and mint.
# Add the cucumber wedge , apple , orange , lemon , lime , pineapple , strawberries , and mint
#
# =========
# Refrigerate until cold, or serve over ice.
#
# serve  over #np#
#
# =========
# Pour limeade, tequila, water, and beer into a large pitcher.
#
#
# =========
# Stir until well-blended, and limeade has melted.
# Stir  until #np#
#
# =========
# Add plenty of ice, and garnish with lime wedges.
# Add plenty of ice
#
# =========
# Adjust with additional water, if needed.
#
# Adjust  with #np#
#
# =========
# In a blender, combine coconut milk, pineapple juice, rum, sugar and ice.
# combine coconut milk , pineapple juice , rum , sugar and ice In #np#
#
# =========
# Blend until smooth.
#
#
# =========
# Pour into glasses, and serve immediately.
#
# serve
#
# =========
# Pour all the ingredients into a shaker with lots of ice.
# Pour all the ingredients into #np# with #np#
#
# =========
# Shake vigorously for several seconds and strain into a cocktail glass.
# strain  into #np#
#
# =========
# Garnish with a lime twist.
#
#
#
# =========
# Mix three parts of your favorite sparkling white to one part of your favorite orange juice.
# Mix three parts of your favorite sparkling white to #np#
#
# =========
# Enjoy!
#
# Enjoy
#
# =========
# Pour the pineapple juice, vodka and grenadine into a shaker full of ice.
# Pour the pineapple juice , vodka and grenadine into #np#
#
# =========
# Shake, then strain into two martini glasses.
# strain  into #np#
#
# =========
# Garnish with a piece of pineapple and a cherry on a skewer.
#
#
#
# =========
# Fill a tall glass with ice.
# Fill a tall glass with #np#
#
# =========
# Pour in vodka.
# Pour  in #np#
#
# =========
# Fill glass to 3/4 full with cranberry juice.
# Fill glass to #np#
#
# =========
# Top with orange juice.
#
#
# =========
# Stir.

# %%
def verb_tracer(s):
    # look for the verb on the sentence
    verb = ""
    for word in s:
        if word.tag_ == "VB":
            verb = word
    # if there's no verb, return ""
    if verb is "":
        return ""
    # if the verb has children, go through them looking for "prep" and "dobj"
    elif len(list(verb.children)) > 0:
        # get the prep
        prep_children = [ch for ch in list(verb.children) if ch.dep_ == "prep"]
        # join them for tracery
        prep_text = " ".join([ch.text+" #np#" for ch in prep_children])
        # get the dobj
        dobj_children = [ch for ch in list(verb.children) if ch.dep_ == "dobj"]
        # joint them as a string
        dobj_text = ""
        for ch in dobj_children:
            dobj_text += " ".join([word.text for word in ch.subtree])
        # get the noun_chunks from the sentence and replace them with
        # a tracery placeholder in the dobj_text
        chunks = s.noun_chunks
        for ch in chunks:
            dobj_text = dobj_text.replace(ch.text, "#np#")
        # return the beautiful phrase
        return verb.text + " " + dobj_text + " " + prep_text
    # else, just return the verb + a tracery placeholder
    else:
        return verb.text+" #np#"
    
# def subtree_flatten(children_list):
#     sub = []
#     for ch in children_list:
#         sub.append(" ".join([word.text for word in ch.subtree]))
#     return " ".join(sub)

# %%
verb_tracer(nlp_instructions[1][1])
# Out:
# 'release #np# oils and #np# juice '

# %%
aux_chunks = nlp_instructions[1][1].noun_chunks
for chunk in aux_chunks:
    print(chunk.text)
# Out:
# a muddler
# the mint
# lime
# the mint oils
# lime juice

# %%
# final function
for instr_set in nlp_instructions:
    for sent in instr_set:
        print("")
        print("=========")
        print(sent.text)
        print(verb_tracer(sent))
# Out:
# =========
# Combine rum and ginger beer in an old-fashioned glass.
# Combine #np#
#
# =========
# Add ice and stir.
#
# stir #np#
#
# =========
# Place mint leaves and 1 lime wedge into a sturdy glass.
# Place #np#
#
# =========
# Use a muddler to crush the mint and lime to release the mint oils and lime juice.
# release #np# oils and #np# juice
#
# =========
# Add 2 more lime wedges and the sugar, and muddle again to release the lime juice.
# release #np#
#
# =========
# Do not strain the mixture.
# strain #np#
#
# =========
# Fill the glass almost to the top with ice.
# Fill #np# to #np# with #np#
#
# =========
# Pour the rum over the ice, and fill the glass with carbonated water.
# fill #np# with #np#
#
# =========
# Stir, taste, and add more sugar if desired.
# add #np#
#
# =========
# Garnish with the remaining lime wedge.
#
#
#
# =========
# Measure the tequila, lime juice, sweetened lime juice and triple sec into a cocktail shaker and add a generous scoop of ice.
# add #np# of #np#
#
# =========
# Cover and shake until the shaker is frosty, about 30 seconds.
#
# shake
#
# =========
# Rub a lime wedge around the rim of a margarita glass and dip in salt.
# Rub #np# around #np#
#
# =========
# Fill each glass with ice.
# Fill #np# with #np#
#
# =========
# Strain equal amounts of the cocktail into the glasses to serve.
# serve
#
# =========
# Garnish with a lime wedge.
#
#
#
# =========
# Put 3 mint leaves and 2 teaspoons sugar into each of 2 glass tumblers; vigorously stir sugar and mint together, crushing mint with the back of a spoon to release oils.
# release #np#
#
# =========
# Add 3 lime wedges to each glass; again stir vigorously to release some lime juice.
# release #np#
#
# =========
# Pour 1 jigger rum into each glass.
#
#
# =========
# Fill glasses with ice cubes and top with carbonated water; stir.
#
# Fill #np# with #np#
#
# =========
# In a large pitcher, stir together the Bloody Mary mix, horseradish, dill, hot pepper sauce, and dill pickle juice.
# stir #np# , #np# , #np# , #np# , and #np# pickle juice In #np#
#
# =========
# Taste and adjust seasoning if desired.
#
# adjust #np#
#
# =========
# In a shallow dish, stir together the kosher salt, pepper and celery seed.
# stir #np# , #np# and #np# #np# In #np#
#
# =========
# Pour the lime juice onto a saucer.
# Pour #np# onto #np#
#
# =========
# Dip each glass into the lime juice to coat the rim, then into the spice mixture.
# coat #np#
#
# =========
# Fill each glass with ice.
# Fill #np# with #np#
#
# =========
# Pour one shot of vodka into each glass if using.
# Pour #np# of #np# into #np#
#
# =========
# Fill with the Bloody Mary mixture.
# Fill  with #np#
#
# =========
# Garnish each glass with a wedge of lime and a dill pickle spear.
#
#
#
# =========
# Fill a blender with ice and crush.
# Fill #np# with #np#
#
# =========
# Pour in the tequila and triple sec.
# Pour  in #np#
#
# =========
# Add the strawberries and limeade.
# Add #np# and #np#
#
# =========
# Blend for 30 seconds or until smooth.
# Blend  for #np#
#
# =========
# Serve in margarita glasses with the rims dipped in powdered sugar.
#
# Serve  in #np# with #np#
#
# =========
# Stir together the Pimm's liqueur and lemonade together in a serving pitcher.
# Stir the Pimm 's liqueur and #np# in #np#
#
# =========
# Add the cucumber wedge, apple, orange, lemon, lime, pineapple, strawberries, and mint.
# Add #np# , #np# , orange , #np# , #np# , pine#np# , #np# , and #np#
#
# =========
# Refrigerate until cold, or serve over ice.
#
# serve  over #np#
#
# =========
# Pour limeade, tequila, water, and beer into a large pitcher.
#
#
# =========
# Stir until well-blended, and limeade has melted.
# Stir  until #np#
#
# =========
# Add plenty of ice, and garnish with lime wedges.
# Add #np# of #np#
#
# =========
# Adjust with additional water, if needed.
#
# Adjust  with #np#
#
# =========
# In a blender, combine coconut milk, pineapple juice, rum, sugar and ice.
# combine #np# , #np# , #np# , #np# and #np# In #np#
#
# =========
# Blend until smooth.
#
#
# =========
# Pour into glasses, and serve immediately.
#
# serve
#
# =========
# Pour all the ingredients into a shaker with lots of ice.
# Pour #np# into #np# with #np#
#
# =========
# Shake vigorously for several seconds and strain into a cocktail glass.
# strain  into #np#
#
# =========
# Garnish with a lime twist.
#
#
#
# =========
# Mix three parts of your favorite sparkling white to one part of your favorite orange juice.
# Mix #np# of your favorite sparkling white to #np#
#
# =========
# Enjoy!
#
# Enjoy
#
# =========
# Pour the pineapple juice, vodka and grenadine into a shaker full of ice.
# Pour #np# , #np# and #np# into #np#
#
# =========
# Shake, then strain into two martini glasses.
# strain  into #np#
#
# =========
# Garnish with a piece of pineapple and a cherry on a skewer.
#
#
#
# =========
# Fill a tall glass with ice.
# Fill #np# with #np#
#
# =========
# Pour in vodka.
# Pour  in #np#
#
# =========
# Fill glass to 3/4 full with cranberry juice.
# Fill #np# to #np#
#
# =========
# Top with orange juice.
#
#
# =========
# Stir.

# %% [markdown]
# Finally, it works as I want it! :D
#
#
#
# Now, on to the actual instruction scrapping...

# %%
instr_finish = [instr[-1].text.strip() for instr in nlp_instructions]

# %%
instr_nlp_body = []
[instr_nlp_body.extend(instr[:-1]) for instr in nlp_instructions]
instr_body = [verb_tracer(instr).strip() for instr in instr_nlp_body]
remove_all('', instr_body)

# %%
instr_body
# Out:
# ['Combine #np#',
#  'Place #np#',
#  'release #np# oils and #np# juice',
#  'release #np#',
#  'strain #np#',
#  'Fill #np# to #np# with #np#',
#  'fill #np# with #np#',
#  'add #np#',
#  'add #np# of #np#',
#  'shake',
#  'Rub #np# around #np#',
#  'Fill #np# with #np#',
#  'serve',
#  'release #np#',
#  'release #np#',
#  'stir #np# , #np# , #np# , #np# , and #np# pickle juice In #np#',
#  'adjust #np#',
#  'stir #np# , #np# and #np# #np# In #np#',
#  'Pour #np# onto #np#',
#  'coat #np#',
#  'Fill #np# with #np#',
#  'Pour #np# of #np# into #np#',
#  'Fill  with #np#',
#  'Fill #np# with #np#',
#  'Pour  in #np#',
#  'Add #np# and #np#',
#  'Blend  for #np#',
#  "Stir the Pimm 's liqueur and #np# in #np#",
#  'Add #np# , #np# , orange , #np# , #np# , pine#np# , #np# , and #np#',
#  'Stir  until #np#',
#  'Add #np# of #np#',
#  'combine #np# , #np# , #np# , #np# and #np# In #np#',
#  'Pour #np# into #np# with #np#',
#  'strain  into #np#',
#  'Mix #np# of your favorite sparkling white to #np#',
#  'Pour #np# , #np# and #np# into #np#',
#  'strain  into #np#',
#  'Fill #np# with #np#',
#  'Pour  in #np#',
#  'Fill #np# to #np#']

# %%
instr_finish
# Out:
# ['Add ice and stir.',
#  'Garnish with the remaining lime wedge.',
#  'Garnish with a lime wedge.',
#  'Fill glasses with ice cubes and top with carbonated water; stir.',
#  'Garnish each glass with a wedge of lime and a dill pickle spear.',
#  'Serve in margarita glasses with the rims dipped in powdered sugar.',
#  'Refrigerate until cold, or serve over ice.',
#  'Adjust with additional water, if needed.',
#  'Pour into glasses, and serve immediately.',
#  'Garnish with a lime twist.',
#  'Enjoy!',
#  'Garnish with a piece of pineapple and a cherry on a skewer.',
#  'Stir.']
